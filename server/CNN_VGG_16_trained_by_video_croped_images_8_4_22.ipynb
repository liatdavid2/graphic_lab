# %%
from IPython.display import clear_output
# !pip install imutils
clear_output()

# %%
import numpy as np 
from tqdm import tqdm
import cv2
import os
import shutil
import itertools
import imutils
import matplotlib.pyplot as plt
from sklearn.preprocessing import LabelBinarizer
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, confusion_matrix

import plotly.graph_objs as go
from plotly.offline import init_notebook_mode, iplot
from plotly import tools

from keras.preprocessing.image import ImageDataGenerator
from keras.applications.vgg16 import VGG16, preprocess_input
from keras.applications.xception import Xception, preprocess_input
from keras import layers
from keras.models import Model, Sequential
from tensorflow.keras.optimizers import Adam, RMSprop
from keras.callbacks import EarlyStopping
init_notebook_mode(connected=True)
RANDOM_SEED = 123
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.8.3.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
# !apt-get install tree
clear_output()
# create new folders
# !mkdir TRAIN TEST VAL TRAIN/YES TRAIN/NO TEST/YES TEST/NO VAL/YES VAL/NO
# !tree -d
# Out:
# .
# ├── sample_data
# ├── TEST
# │   ├── NO
# │   └── YES
# ├── TRAIN
# │   ├── NO
# │   └── YES
# └── VAL
#     ├── NO
#     └── YES
#
# 10 directories

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
#IMG_PATH = '/content/gdrive/MyDrive/ml/Brain_Tumor_Detection/'
#IMG_PATH = '/content/gdrive/MyDrive/ml/bus/'
IMG_PATH = '/content/gdrive/MyDrive/ml/cocomelon_jay_jay/'

# split the data by train/val/test
for CLASS in os.listdir(IMG_PATH):
    print(CLASS)
    if not CLASS.startswith('.'):
        IMG_NUM = len(os.listdir(IMG_PATH + CLASS))
        for (n, FILE_NAME) in enumerate(os.listdir(IMG_PATH + CLASS)):
            img = IMG_PATH + CLASS + '/' + FILE_NAME
            print(img)
            if n < 5:
                shutil.copy(img, './TEST/' + CLASS.upper() + '/' + FILE_NAME)
            elif n < 0.8*IMG_NUM:
                shutil.copy(img, './TRAIN/'+ CLASS.upper() + '/' + FILE_NAME)
            else:
                shutil.copy(img, './VAL/'+ CLASS.upper() + '/' + FILE_NAME)
# Out:
# yes
# /content/gdrive/MyDrive/ml/cocomelon_jay_jay/yes/cocomelon5.jpg
# /content/gdrive/MyDrive/ml/cocomelon_jay_jay/yes/cocomelon8.jpg
# /content/gdrive/MyDrive/ml/cocomelon_jay_jay/yes/cocomelon7.jpg
# /content/gdrive/MyDrive/ml/cocomelon_jay_jay/yes/cocomelon6.jpg
# /content/gdrive/MyDrive/ml/cocomelon_jay_jay/yes/cocomelon9.jpg
# /content/gdrive/MyDrive/ml/cocomelon_jay_jay/yes/cocomelon12.jpg
# /content/gdrive/MyDrive/ml/cocomelon_jay_jay/yes/cocomelon11.jpg
# /content/gdrive/MyDrive/ml/cocomelon_jay_jay/yes/cocomelon10.jpg
# /content/gdrive/MyDrive/ml/cocomelon_jay_jay/yes/cocomelon22.jpg
# /content/gdrive/MyDrive/ml/cocomelon_jay_jay/yes/cocomelon19.jpg
# /content/gdrive/MyDrive/ml/cocomelon_jay_jay/yes/cocomelon21.jpg
# /content/gdrive/MyDrive/ml/cocomelon_jay_jay/yes/cocomelon25.jpg
# /content/gdrive/MyDrive/ml/cocomelon_jay_jay/yes/cocomelon27.jpg
# /content/gdrive/MyDrive/ml/cocomelon_jay_jay/yes/cocomelon32.jpg
# /content/gdrive/MyDrive/ml/cocomelon_jay_jay/yes/cocomelon30.jpg
# /content/gdrive/MyDrive/ml/cocomelon_jay_jay/yes/cocomelon103.jpg
# /content/gdrive/MyDrive/ml/cocomelon_jay_jay/yes/cocomelon122.jpg
# /content/gdrive/MyDrive/ml/cocomelon_jay_jay/yes/cocomelon120.jpg
# /content/gdrive/MyDrive/ml/cocomelon_jay_jay/yes/cocomelon133.jpg
# /content/gdrive/MyDrive/ml/cocomelon_jay_jay/yes/cocomelon127.jpg
# /content/gdrive/MyDrive/ml/cocomelon_jay_jay/yes/cocomelon131.jpg
# /content/gdrive/MyDrive/ml/cocomelon_jay_jay/yes/cocomelon124.jpg
# /content/gdrive/MyDrive/ml/cocomelon_jay_jay/yes/cocomelon142.jpg
# /content/gdrive/MyDrive/ml/cocomelon_jay_jay/yes/cocomelon160.jpg
# /content/gdrive/MyDrive/ml/cocomelon_jay_jay/yes/cocomelon176.jpg
# /content/gdrive/MyDrive/ml/cocomelon_jay_jay/yes/cocomelon212.jpg
# /content/gdrive/MyDrive/ml/cocomelon_jay_jay/yes/cocomelon209.jpg
# /content/gdrive/MyDrive/ml/cocomelon_jay_jay/yes/cocomelon263.jpg
# /content/gdrive/MyDrive/ml/cocomelon_jay_jay/yes/cocomelon279.jpg
# /content/gdrive/MyDrive/ml/cocomelon_jay_jay/yes/cocomelon397.jpg
# /content/gdrive/MyDrive/ml/cocomelon_jay_jay/yes/cocomelon398.jpg
# /content/gdrive/MyDrive/ml/cocomelon_jay_jay/yes/cocomelon399.jpg
# /content/gdrive/MyDrive/ml/cocomelon_jay_jay/yes/cocomelon403.jpg
# /content/gdrive/MyDrive/ml/cocomelon_jay_jay/yes/cocomelon405.jpg
# /content/gdrive/MyDrive/ml/cocomelon_jay_jay/yes/cocomelon415.jpg
# /content/gdrive/MyDrive/ml/cocomelon_jay_jay/yes/cocomelon417.jpg
# /content/gdrive/MyDrive/ml/cocomelon_jay_jay/yes/cocomelon409.jpg
# /content/gdrive/MyDrive/ml/cocomelon_jay_jay/yes/cocomelon412.jpg
# /content/gdrive/MyDrive/ml/cocomelon_jay_jay/yes/cocomelon420.jpg
# /content/gdrive/MyDrive/ml/cocomelon_jay_jay/yes/cocomelon425.jpg
# /content/gdrive/MyDrive/ml/cocomelon_jay_jay/yes/cocomelon422.jpg
# /content/gdrive/MyDrive/ml/cocomelon_jay_jay/yes/cocomelon439.jpg
# /content/gdrive/MyDrive/ml/cocomelon_jay_jay/yes/cocomelon444.jpg
# /content/gdrive/MyDrive/ml/cocomelon_jay_jay/yes/cocomelon447.jpg
# /content/gdrive/MyDrive/ml/cocomelon_jay_jay/yes/cocomelon441.jpg
# /content/gdrive/MyDrive/ml/cocomelon_jay_jay/yes/cocomelon451.jpg
# /content/gdrive/MyDrive/ml/cocomelon_jay_jay/yes/cocomelon455.jpg
# /content/gdrive/MyDrive/ml/cocomelon_jay_jay/yes/cocomelon494.jpg
# /content/gdrive/MyDrive/ml/cocomelon_jay_jay/yes/cocomelon495.jpg
# /content/gdrive/MyDrive/ml/cocomelon_jay_jay/yes/cocomelon509.jpg
# /content/gdrive/MyDrive/ml/cocomelon_jay_jay/yes/cocomelon512.jpg
# /content/gdrive/MyDrive/ml/cocomelon_jay_jay/yes/cocomelon515.jpg
# /content/gdrive/MyDrive/ml/cocomelon_jay_jay/yes/cocomelon550.jpg
# /content/gdrive/MyDrive/ml/cocomelon_jay_jay/yes/cocomelon553.jpg
# /content/gdrive/MyDrive/ml/cocomelon_jay_jay/yes/cocomelon590.jpg
# /content/gdrive/MyDrive/ml/cocomelon_jay_jay/yes/cocomelon595.jpg
# /content/gdrive/MyDrive/ml/cocomelon_jay_jay/yes/cocomelon636.jpg
# /content/gdrive/MyDrive/ml/cocomelon_jay_jay/yes/cocomelon638.jpg
# /content/gdrive/MyDrive/ml/cocomelon_jay_jay/yes/cocomelon645.jpg
# /content/gdrive/MyDrive/ml/cocomelon_jay_jay/yes/cocomelon672.jpg
# /content/gdrive/MyDrive/ml/cocomelon_jay_jay/yes/cocomelon669.jpg
# /content/gdrive/MyDrive/ml/cocomelon_jay_jay/yes/cocomelon671.jpg
# /content/gdrive/MyDrive/ml/cocomelon_jay_jay/yes/cocomelon673.jpg
# /content/gdrive/MyDrive/ml/cocomelon_jay_jay/yes/cocomelon675.jpg
# /content/gdrive/MyDrive/ml/cocomelon_jay_jay/yes/cocomelon709.jpg
# /content/gdrive/MyDrive/ml/cocomelon_jay_jay/yes/cocomelon710.jpg
# /content/gdrive/MyDrive/ml/cocomelon_jay_jay/yes/cocomelon711.jpg
# /content/gdrive/MyDrive/ml/cocomelon_jay_jay/yes/cocomelon740.jpg
# /content/gdrive/MyDrive/ml/cocomelon_jay_jay/yes/cocomelon741.jpg
# /content/gdrive/MyDrive/ml/cocomelon_jay_jay/yes/cocomelon749.jpg
# /content/gdrive/MyDrive/ml/cocomelon_jay_jay/yes/cocomelon751.jpg
# /content/gdrive/MyDrive/ml/cocomelon_jay_jay/yes/cocomelon758.jpg
# /content/gdrive/MyDrive/ml/cocomelon_jay_jay/yes/cocomelon808.jpg
# /content/gdrive/MyDrive/ml/cocomelon_jay_jay/yes/cocomelon810.jpg
# /content/gdrive/MyDrive/ml/cocomelon_jay_jay/yes/cocomelon809.jpg
# /content/gdrive/MyDrive/ml/cocomelon_jay_jay/yes/cocomelon811.jpg
# /content/gdrive/MyDrive/ml/cocomelon_jay_jay/yes/cocomelon812.jpg
# /content/gdrive/MyDrive/ml/cocomelon_jay_jay/yes/cocomelon819.jpg
# /content/gdrive/MyDrive/ml/cocomelon_jay_jay/yes/cocomelon840.jpg
# /content/gdrive/MyDrive/ml/cocomelon_jay_jay/yes/cocomelon842.jpg
# /content/gdrive/MyDrive/ml/cocomelon_jay_jay/yes/cocomelon844.jpg
# /content/gdrive/MyDrive/ml/cocomelon_jay_jay/yes/cocomelon845.jpg
# /content/gdrive/MyDrive/ml/cocomelon_jay_jay/yes/cocomelon841.jpg
# /content/gdrive/MyDrive/ml/cocomelon_jay_jay/yes/cocomelon846.jpg
# /content/gdrive/MyDrive/ml/cocomelon_jay_jay/yes/cocomelon847.jpg
# /content/gdrive/MyDrive/ml/cocomelon_jay_jay/yes/cocomelon848.jpg
# /content/gdrive/MyDrive/ml/cocomelon_jay_jay/yes/cocomelon852.jpg
# /content/gdrive/MyDrive/ml/cocomelon_jay_jay/yes/cocomelon849.jpg
# /content/gdrive/MyDrive/ml/cocomelon_jay_jay/yes/cocomelon850.jpg
# /content/gdrive/MyDrive/ml/cocomelon_jay_jay/yes/cocomelon851.jpg
# /content/gdrive/MyDrive/ml/cocomelon_jay_jay/yes/cocomelon854.jpg
# /content/gdrive/MyDrive/ml/cocomelon_jay_jay/yes/cocomelon856.jpg
# /content/gdrive/MyDrive/ml/cocomelon_jay_jay/yes/cocomelon853.jpg
# /content/gdrive/MyDrive/ml/cocomelon_jay_jay/yes/cocomelon857.jpg
# /content/gdrive/MyDrive/ml/cocomelon_jay_jay/yes/cocomelon855.jpg
# /content/gdrive/MyDrive/ml/cocomelon_jay_jay/yes/cocomelon861.jpg
# /content/gdrive/MyDrive/ml/cocomelon_jay_jay/yes/cocomelon859.jpg
# /content/gdrive/MyDrive/ml/cocomelon_jay_jay/yes/cocomelon862.jpg
# /content/gdrive/MyDrive/ml/cocomelon_jay_jay/yes/cocomelon858.jpg
# /content/gdrive/MyDrive/ml/cocomelon_jay_jay/yes/cocomelon864.jpg
# /content/gdrive/MyDrive/ml/cocomelon_jay_jay/yes/cocomelon866.jpg
# /content/gdrive/MyDrive/ml/cocomelon_jay_jay/yes/cocomelon865.jpg
# /content/gdrive/MyDrive/ml/cocomelon_jay_jay/yes/cocomelon863.jpg
# /content/gdrive/MyDrive/ml/cocomelon_jay_jay/yes/cocomelon867.jpg
# /content/gdrive/MyDrive/ml/cocomelon_jay_jay/yes/cocomelon868.jpg
# /content/gdrive/MyDrive/ml/cocomelon_jay_jay/yes/cocomelon869.jpg
# /content/gdrive/MyDrive/ml/cocomelon_jay_jay/yes/cocomelon870.jpg
# /content/gdrive/MyDrive/ml/cocomelon_jay_jay/yes/cocomelon871.jpg
# /content/gdrive/MyDrive/ml/cocomelon_jay_jay/yes/cocomelon872.jpg
# /content/gdrive/MyDrive/ml/cocomelon_jay_jay/yes/cocomelon874.jpg
# /content/gdrive/MyDrive/ml/cocomelon_jay_jay/yes/cocomelon876.jpg
# /content/gdrive/MyDrive/ml/cocomelon_jay_jay/yes/cocomelon873.jpg
# /content/gdrive/MyDrive/ml/cocomelon_jay_jay/yes/cocomelon877.jpg
# /content/gdrive/MyDrive/ml/cocomelon_jay_jay/yes/cocomelon878.jpg
# /content/gdrive/MyDrive/ml/cocomelon_jay_jay/yes/cocomelon879.jpg
# /content/gdrive/MyDrive/ml/cocomelon_jay_jay/yes/cocomelon1067.jpg
# /content/gdrive/MyDrive/ml/cocomelon_jay_jay/yes/cocomelon1071.jpg
# /content/gdrive/MyDrive/ml/cocomelon_jay_jay/yes/cocomelon1069.jpg
# /content/gdrive/MyDrive/ml/cocomelon_jay_jay/yes/cocomelon1073.jpg
# /content/gdrive/MyDrive/ml/cocomelon_jay_jay/yes/cocomelon1075.jpg
# /content/gdrive/MyDrive/ml/cocomelon_jay_jay/yes/cocomelon1082.jpg
# /content/gdrive/MyDrive/ml/cocomelon_jay_jay/yes/cocomelon1085.jpg
# /content/gdrive/MyDrive/ml/cocomelon_jay_jay/yes/cocomelon1084.jpg
# no
# /content/gdrive/MyDrive/ml/cocomelon_jay_jay/no/cocomelon13.jpg
# /content/gdrive/MyDrive/ml/cocomelon_jay_jay/no/cocomelon16.jpg
# /content/gdrive/MyDrive/ml/cocomelon_jay_jay/no/cocomelon14.jpg
# /content/gdrive/MyDrive/ml/cocomelon_jay_jay/no/cocomelon15.jpg
# /content/gdrive/MyDrive/ml/cocomelon_jay_jay/no/cocomelon24.jpg
# /content/gdrive/MyDrive/ml/cocomelon_jay_jay/no/cocomelon20.jpg
# /content/gdrive/MyDrive/ml/cocomelon_jay_jay/no/cocomelon17.jpg
# /content/gdrive/MyDrive/ml/cocomelon_jay_jay/no/cocomelon23.jpg
# /content/gdrive/MyDrive/ml/cocomelon_jay_jay/no/cocomelon18.jpg
# /content/gdrive/MyDrive/ml/cocomelon_jay_jay/no/cocomelon216.jpg
# /content/gdrive/MyDrive/ml/cocomelon_jay_jay/no/cocomelon228.jpg
# /content/gdrive/MyDrive/ml/cocomelon_jay_jay/no/cocomelon222.jpg
# /content/gdrive/MyDrive/ml/cocomelon_jay_jay/no/cocomelon224.jpg
# /content/gdrive/MyDrive/ml/cocomelon_jay_jay/no/cocomelon231.jpg
# /content/gdrive/MyDrive/ml/cocomelon_jay_jay/no/cocomelon230.jpg
# /content/gdrive/MyDrive/ml/cocomelon_jay_jay/no/cocomelon233.jpg
# /content/gdrive/MyDrive/ml/cocomelon_jay_jay/no/cocomelon232.jpg
# /content/gdrive/MyDrive/ml/cocomelon_jay_jay/no/cocomelon229.jpg
# /content/gdrive/MyDrive/ml/cocomelon_jay_jay/no/cocomelon234.jpg
# /content/gdrive/MyDrive/ml/cocomelon_jay_jay/no/cocomelon371.jpg
# /content/gdrive/MyDrive/ml/cocomelon_jay_jay/no/cocomelon372.jpg
# /content/gdrive/MyDrive/ml/cocomelon_jay_jay/no/cocomelon375.jpg
# /content/gdrive/MyDrive/ml/cocomelon_jay_jay/no/cocomelon374.jpg
# /content/gdrive/MyDrive/ml/cocomelon_jay_jay/no/cocomelon373.jpg
# /content/gdrive/MyDrive/ml/cocomelon_jay_jay/no/cocomelon378.jpg
# /content/gdrive/MyDrive/ml/cocomelon_jay_jay/no/cocomelon376.jpg
# /content/gdrive/MyDrive/ml/cocomelon_jay_jay/no/cocomelon377.jpg
# /content/gdrive/MyDrive/ml/cocomelon_jay_jay/no/cocomelon392.jpg
# /content/gdrive/MyDrive/ml/cocomelon_jay_jay/no/cocomelon545.jpg
# /content/gdrive/MyDrive/ml/cocomelon_jay_jay/no/cocomelon543.jpg
# /content/gdrive/MyDrive/ml/cocomelon_jay_jay/no/cocomelon544.jpg
# /content/gdrive/MyDrive/ml/cocomelon_jay_jay/no/cocomelon734.jpg
# /content/gdrive/MyDrive/ml/cocomelon_jay_jay/no/cocomelon1022.jpg
# /content/gdrive/MyDrive/ml/cocomelon_jay_jay/no/cocomelon1023.jpg
# /content/gdrive/MyDrive/ml/cocomelon_jay_jay/no/cocomelon1021.jpg
# /content/gdrive/MyDrive/ml/cocomelon_jay_jay/no/cocomelon1025.jpg
# /content/gdrive/MyDrive/ml/cocomelon_jay_jay/no/cocomelon1026.jpg
# /content/gdrive/MyDrive/ml/cocomelon_jay_jay/no/cocomelon1024.jpg
# /content/gdrive/MyDrive/ml/cocomelon_jay_jay/no/cocomelon1054.jpg
# /content/gdrive/MyDrive/ml/cocomelon_jay_jay/no/cocomelon1055.jpg
# /content/gdrive/MyDrive/ml/cocomelon_jay_jay/no/cocomelon1056.jpg
# /content/gdrive/MyDrive/ml/cocomelon_jay_jay/no/cocomelon1058.jpg
# /content/gdrive/MyDrive/ml/cocomelon_jay_jay/no/cocomelon1059.jpg
# /content/gdrive/MyDrive/ml/cocomelon_jay_jay/no/cocomelon1057.jpg
# /content/gdrive/MyDrive/ml/cocomelon_jay_jay/no/cocomelon1062.jpg
# /content/gdrive/MyDrive/ml/cocomelon_jay_jay/no/cocomelon1061.jpg
# /content/gdrive/MyDrive/ml/cocomelon_jay_jay/no/cocomelon1153.jpg
# /content/gdrive/MyDrive/ml/cocomelon_jay_jay/no/cocomelon1158.jpg
# /content/gdrive/MyDrive/ml/cocomelon_jay_jay/no/cocomelon1157.jpg
# /content/gdrive/MyDrive/ml/cocomelon_jay_jay/no/cocomelon1156.jpg
# /content/gdrive/MyDrive/ml/cocomelon_jay_jay/no/cocomelon1155.jpg
# /content/gdrive/MyDrive/ml/cocomelon_jay_jay/no/cocomelon1154.jpg
# /content/gdrive/MyDrive/ml/cocomelon_jay_jay/no/cocomelon1161.jpg
# /content/gdrive/MyDrive/ml/cocomelon_jay_jay/no/cocomelon1159.jpg
# /content/gdrive/MyDrive/ml/cocomelon_jay_jay/no/cocomelon1160.jpg
# /content/gdrive/MyDrive/ml/cocomelon_jay_jay/no/cocomelon1227.jpg
# /content/gdrive/MyDrive/ml/cocomelon_jay_jay/no/cocomelon1226.jpg
# /content/gdrive/MyDrive/ml/cocomelon_jay_jay/no/cocomelon1225.jpg
# /content/gdrive/MyDrive/ml/cocomelon_jay_jay/no/cocomelon1228.jpg
# /content/gdrive/MyDrive/ml/cocomelon_jay_jay/no/cocomelon1229.jpg
# /content/gdrive/MyDrive/ml/cocomelon_jay_jay/no/cocomelon1230.jpg
# /content/gdrive/MyDrive/ml/cocomelon_jay_jay/no/cocomelon1231.jpg
# /content/gdrive/MyDrive/ml/cocomelon_jay_jay/no/cocomelon1233.jpg
# /content/gdrive/MyDrive/ml/cocomelon_jay_jay/no/cocomelon1232.jpg
# /content/gdrive/MyDrive/ml/cocomelon_jay_jay/no/cocomelon1450.jpg
# /content/gdrive/MyDrive/ml/cocomelon_jay_jay/no/cocomelon1452.jpg
# /content/gdrive/MyDrive/ml/cocomelon_jay_jay/no/cocomelon1451.jpg
# /content/gdrive/MyDrive/ml/cocomelon_jay_jay/no/cocomelon1453.jpg
# /content/gdrive/MyDrive/ml/cocomelon_jay_jay/no/cocomelon1454.jpg
# /content/gdrive/MyDrive/ml/cocomelon_jay_jay/no/cocomelon1455.jpg
# /content/gdrive/MyDrive/ml/cocomelon_jay_jay/no/cocomelon1456.jpg
# /content/gdrive/MyDrive/ml/cocomelon_jay_jay/no/cocomelon1457.jpg
# /content/gdrive/MyDrive/ml/cocomelon_jay_jay/no/cocomelon1458.jpg
# /content/gdrive/MyDrive/ml/cocomelon_jay_jay/no/cocomelon1477.jpg
# /content/gdrive/MyDrive/ml/cocomelon_jay_jay/no/cocomelon1479.jpg
# /content/gdrive/MyDrive/ml/cocomelon_jay_jay/no/cocomelon1480.jpg
# /content/gdrive/MyDrive/ml/cocomelon_jay_jay/no/cocomelon1478.jpg
# /content/gdrive/MyDrive/ml/cocomelon_jay_jay/no/cocomelon1482.jpg
# /content/gdrive/MyDrive/ml/cocomelon_jay_jay/no/cocomelon1481.jpg
# /content/gdrive/MyDrive/ml/cocomelon_jay_jay/no/cocomelon1483.jpg
# /content/gdrive/MyDrive/ml/cocomelon_jay_jay/no/cocomelon1484.jpg
# /content/gdrive/MyDrive/ml/cocomelon_jay_jay/no/cocomelon1485.jpg
# /content/gdrive/MyDrive/ml/cocomelon_jay_jay/no/cocomelon1560.jpg
# /content/gdrive/MyDrive/ml/cocomelon_jay_jay/no/cocomelon1562.jpg
# /content/gdrive/MyDrive/ml/cocomelon_jay_jay/no/cocomelon1563.jpg
# /content/gdrive/MyDrive/ml/cocomelon_jay_jay/no/cocomelon1561.jpg
# /content/gdrive/MyDrive/ml/cocomelon_jay_jay/no/cocomelon1564.jpg
# /content/gdrive/MyDrive/ml/cocomelon_jay_jay/no/cocomelon1566.jpg
# /content/gdrive/MyDrive/ml/cocomelon_jay_jay/no/cocomelon1565.jpg
# /content/gdrive/MyDrive/ml/cocomelon_jay_jay/no/cocomelon1783.jpg
# /content/gdrive/MyDrive/ml/cocomelon_jay_jay/no/cocomelon1786.jpg
# /content/gdrive/MyDrive/ml/cocomelon_jay_jay/no/cocomelon1785.jpg
# /content/gdrive/MyDrive/ml/cocomelon_jay_jay/no/cocomelon1784.jpg
# /content/gdrive/MyDrive/ml/cocomelon_jay_jay/no/cocomelon1787.jpg
# /content/gdrive/MyDrive/ml/cocomelon_jay_jay/no/cocomelon1789.jpg
# /content/gdrive/MyDrive/ml/cocomelon_jay_jay/no/cocomelon1790.jpg
# /content/gdrive/MyDrive/ml/cocomelon_jay_jay/no/cocomelon1788.jpg
# /content/gdrive/MyDrive/ml/cocomelon_jay_jay/no/cocomelon1791.jpg
# /content/gdrive/MyDrive/ml/cocomelon_jay_jay/no/cocomelon1794.jpg
# /content/gdrive/MyDrive/ml/cocomelon_jay_jay/no/cocomelon1793.jpg
# /content/gdrive/MyDrive/ml/cocomelon_jay_jay/no/cocomelon1792.jpg
# /content/gdrive/MyDrive/ml/cocomelon_jay_jay/no/cocomelon1795.jpg
# /content/gdrive/MyDrive/ml/cocomelon_jay_jay/no/cocomelon1796.jpg
# /content/gdrive/MyDrive/ml/cocomelon_jay_jay/no/cocomelon1798.jpg
# /content/gdrive/MyDrive/ml/cocomelon_jay_jay/no/cocomelon1797.jpg
# /content/gdrive/MyDrive/ml/cocomelon_jay_jay/no/cocomelon1799.jpg
# /content/gdrive/MyDrive/ml/cocomelon_jay_jay/no/cocomelon1800.jpg
# /content/gdrive/MyDrive/ml/cocomelon_jay_jay/no/cocomelon1810.jpg
# /content/gdrive/MyDrive/ml/cocomelon_jay_jay/no/cocomelon1812.jpg
# /content/gdrive/MyDrive/ml/cocomelon_jay_jay/no/cocomelon1811.jpg
# /content/gdrive/MyDrive/ml/cocomelon_jay_jay/no/cocomelon1813.jpg
# /content/gdrive/MyDrive/ml/cocomelon_jay_jay/no/cocomelon1814.jpg
# /content/gdrive/MyDrive/ml/cocomelon_jay_jay/no/cocomelon1815.jpg
# /content/gdrive/MyDrive/ml/cocomelon_jay_jay/no/cocomelon1816.jpg
# /content/gdrive/MyDrive/ml/cocomelon_jay_jay/no/cocomelon1817.jpg
# /content/gdrive/MyDrive/ml/cocomelon_jay_jay/no/cocomelon1818.jpg
# /content/gdrive/MyDrive/ml/cocomelon_jay_jay/no/cocomelon1917.jpg
# /content/gdrive/MyDrive/ml/cocomelon_jay_jay/no/cocomelon1920.jpg

# %%
def load_data(dir_path, img_size=(100,100)):
    """
    Load resized images as np.arrays to workspace
    """
    X = []
    y = []
    i = 0
    labels = dict()
    for path in tqdm(sorted(os.listdir(dir_path))):
        if not path.startswith('.'):
            labels[i] = path
            for file in os.listdir(dir_path + path):
                if not file.startswith('.'):
                    img = cv2.imread(dir_path + path + '/' + file)
                    X.append(img)
                    y.append(i)
            i += 1
    X = np.array(X)
    y = np.array(y)
    print(f'{len(X)} images loaded from {dir_path} directory.')
    return X, y, labels



def plot_confusion_matrix(cm, classes,
                          normalize=False,
                          title='Confusion matrix',
                          cmap=plt.cm.Blues):
    """
    This function prints and plots the confusion matrix.
    Normalization can be applied by setting `normalize=True`.
    """
    plt.figure(figsize = (6,6))
    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=90)
    plt.yticks(tick_marks, classes)
    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]

    thresh = cm.max() / 2.
    cm = np.round(cm,2)
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, cm[i, j],
                 horizontalalignment="center",
                 color="white" if cm[i, j] > thresh else "black")
    plt.tight_layout()
    plt.ylabel('True label')
    plt.xlabel('Predicted label')
    plt.show()

# %%
TRAIN_DIR = 'TRAIN/'
TEST_DIR = 'TEST/'
VAL_DIR = 'VAL/'
IMG_SIZE = (224,224)

# use predefined function to load the image data into workspace
X_train, y_train, labels = load_data(TRAIN_DIR, IMG_SIZE)
X_test, y_test, _ = load_data(TEST_DIR, IMG_SIZE)
X_val, y_val, _ = load_data(VAL_DIR, IMG_SIZE)
# Out:
# 100%|██████████| 2/2 [00:00<00:00,  7.04it/s]
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:18: VisibleDeprecationWarning:
#
# Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
# 184 images loaded from TRAIN/ directory.
# 100%|██████████| 2/2 [00:00<00:00, 128.75it/s]
# 10 images loaded from TEST/ directory.
# 100%|██████████| 2/2 [00:00<00:00, 24.38it/s]
# 47 images loaded from VAL/ directory.

# %%
y = dict()
y[0] = []
y[1] = []
for set_name in (y_train, y_val, y_test):
    y[0].append(np.sum(set_name == 0))
    y[1].append(np.sum(set_name == 1))

trace0 = go.Bar(
    x=['Train Set', 'Validation Set', 'Test Set'],
    y=y[0],
    name='No',
    marker=dict(color='#33cc33'),
    opacity=0.7
)
trace1 = go.Bar(
    x=['Train Set', 'Validation Set', 'Test Set'],
    y=y[1],
    name='Yes',
    marker=dict(color='#ff3300'),
    opacity=0.7
)
data = [trace0, trace1]
layout = go.Layout(
    title='Count of classes in each set',
    xaxis={'title': 'Set'},
    yaxis={'title': 'Count'}
)
fig = go.Figure(data, layout)
iplot(fig)
# Out:
# <div>                            <div id="8d4f1768-cc22-48c1-9eb2-875a2c3c8a85" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("8d4f1768-cc22-48c1-9eb2-875a2c3c8a85")) {                    Plotly.newPlot(                        "8d4f1768-cc22-48c1-9eb2-875a2c3c8a85",                        [{"marker":{"color":"#33cc33"},"name":"No","opacity":0.7,"x":["Train Set","Validation Set","Test Set"],"y":[90,23,5],"type":"bar"},{"marker":{"color":"#ff3300"},"name":"Yes","opacity":0.7,"x":["Train Set","Validation Set","Test Set"],"y":[94,24,5],"type":"bar"}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2dcontour"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2d"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"mesh3d":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"mesh3d"}],"parcoords":[{"line":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"parcoords"}],"pie":[{"automargin":true,"type":"pie"}],"scatter3d":[{"line":{"colorbar":{"outlinewidth":0,"ticks":""}},"marker":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"scatter3d"}],"scattercarpet":[{"marker":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"s ...
#
# var gd = document.getElementById('8d4f1768-cc22-

# %%
def plot_samples(X, y, labels_dict, n=50):
    """
    Creates a gridplot for desired number of images (n) from the specified set
    """
    for index in range(len(labels_dict)):
        imgs = X[np.argwhere(y == index)][:n]
        j = 10
        i = int(n/j)

        plt.figure(figsize=(15,6))
        c = 1
        for img in imgs:
            plt.subplot(i,j,c)
            plt.imshow(img[0])

            plt.xticks([])
            plt.yticks([])
            c += 1
        plt.suptitle('Tumor: {}'.format(labels_dict[index]))
        plt.show()

# %%
plot_samples(X_train, y_train, labels, 30)

# %%
RATIO_LIST = []
for set in (X_train, X_test, X_val):
    for img in set:
        RATIO_LIST.append(img.shape[1]/img.shape[0])
        
plt.hist(RATIO_LIST)
plt.title('Distribution of Image Ratios')
plt.xlabel('Ratio Value')
plt.ylabel('Count')
plt.show()

# %%
def crop_imgs(set_name, add_pixels_value=0):
    """
    Finds the extreme points on the image and crops the rectangular out of them
    """
    set_new = []
    for img in set_name:
        gray = cv2.cvtColor(img, cv2.COLOR_RGB2GRAY)
        gray = cv2.GaussianBlur(gray, (5, 5), 0)

        # threshold the image, then perform a series of erosions +
        # dilations to remove any small regions of noise
        thresh = cv2.threshold(gray, 45, 255, cv2.THRESH_BINARY)[1]
        thresh = cv2.erode(thresh, None, iterations=2)
        thresh = cv2.dilate(thresh, None, iterations=2)

        # find contours in thresholded image, then grab the largest one
        cnts = cv2.findContours(thresh.copy(), cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)
        cnts = imutils.grab_contours(cnts)
        c = max(cnts, key=cv2.contourArea)

        # find the extreme points
        extLeft = tuple(c[c[:, :, 0].argmin()][0])
        extRight = tuple(c[c[:, :, 0].argmax()][0])
        extTop = tuple(c[c[:, :, 1].argmin()][0])
        extBot = tuple(c[c[:, :, 1].argmax()][0])

        ADD_PIXELS = add_pixels_value
        new_img = img[extTop[1]-ADD_PIXELS:extBot[1]+ADD_PIXELS, extLeft[0]-ADD_PIXELS:extRight[0]+ADD_PIXELS].copy()
        set_new.append(new_img)

    return np.array(set_new)

# %%
img = cv2.imread('/content/gdrive/MyDrive/ml/bus/yes/bus.jpg')
img = cv2.imread('/content/gdrive/MyDrive/ml/cocomelon_jay_jay/yes/cocomelon7.jpg')

img = cv2.resize(
            img,
            dsize=IMG_SIZE,
            interpolation=cv2.INTER_CUBIC
        )
gray = cv2.cvtColor(img, cv2.COLOR_RGB2GRAY)
gray = cv2.GaussianBlur(gray, (5, 5), 0)

# threshold the image, then perform a series of erosions +
# dilations to remove any small regions of noise
thresh = cv2.threshold(gray, 45, 255, cv2.THRESH_BINARY)[1]
thresh = cv2.erode(thresh, None, iterations=2)
thresh = cv2.dilate(thresh, None, iterations=2)

# find contours in thresholded image, then grab the largest one
cnts = cv2.findContours(thresh.copy(), cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)
cnts = imutils.grab_contours(cnts)
c = max(cnts, key=cv2.contourArea)

# find the extreme points
extLeft = tuple(c[c[:, :, 0].argmin()][0])
extRight = tuple(c[c[:, :, 0].argmax()][0])
extTop = tuple(c[c[:, :, 1].argmin()][0])
extBot = tuple(c[c[:, :, 1].argmax()][0])

# add contour on the image
img_cnt = cv2.drawContours(img.copy(), [c], -1, (0, 255, 255), 4)

# add extreme points
img_pnt = cv2.circle(img_cnt.copy(), extLeft, 8, (0, 0, 255), -1)
img_pnt = cv2.circle(img_pnt, extRight, 8, (0, 255, 0), -1)
img_pnt = cv2.circle(img_pnt, extTop, 8, (255, 0, 0), -1)
img_pnt = cv2.circle(img_pnt, extBot, 8, (255, 255, 0), -1)

# crop
ADD_PIXELS = 0
new_img = img[extTop[1]-ADD_PIXELS:extBot[1]+ADD_PIXELS, extLeft[0]-ADD_PIXELS:extRight[0]+ADD_PIXELS].copy()

# %%
plt.figure(figsize=(15,6))
plt.subplot(141)
plt.imshow(img)
plt.xticks([])
plt.yticks([])
plt.title('Step 1. Get the original image')
plt.subplot(142)
plt.imshow(img_cnt)
plt.xticks([])
plt.yticks([])
plt.title('Step 2. Find the biggest contour')
plt.subplot(143)
plt.imshow(img_pnt)
plt.xticks([])
plt.yticks([])
plt.title('Step 3. Find the extreme points')
plt.subplot(144)
plt.imshow(new_img)
plt.xticks([])
plt.yticks([])
plt.title('Step 4. Crop the image')
plt.show()

# %%
# apply this for each set
X_train_crop = crop_imgs(set_name=X_train)
X_val_crop = crop_imgs(set_name=X_val)
X_test_crop = crop_imgs(set_name=X_test)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:31: VisibleDeprecationWarning:
#
# Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.

# %%
plot_samples(X_train_crop, y_train, labels, 30)

# %%
def save_new_images(x_set, y_set, folder_name):
    i = 0
    for (img, imclass) in zip(x_set, y_set):
        if imclass == 0:
            cv2.imwrite(folder_name+'NO/'+str(i)+'.jpg', img)
        else:
            cv2.imwrite(folder_name+'YES/'+str(i)+'.jpg', img)
        i += 1

# %%
# saving new images to the folder
# !mkdir TRAIN_CROP TEST_CROP VAL_CROP TRAIN_CROP/YES TRAIN_CROP/NO TEST_CROP/YES TEST_CROP/NO VAL_CROP/YES VAL_CROP/NO

save_new_images(X_train_crop, y_train, folder_name='TRAIN_CROP/')
save_new_images(X_val_crop, y_val, folder_name='VAL_CROP/')
save_new_images(X_test_crop, y_test, folder_name='TEST_CROP/')

# %%
def preprocess_imgs(set_name, img_size):
    """
    Resize and apply VGG-15 preprocessing
    """
    set_new = []
    for img in set_name:
        img = cv2.resize(
            img,
            dsize=img_size,
            interpolation=cv2.INTER_CUBIC
        )
        set_new.append(preprocess_input(img))
    return np.array(set_new)

# %%
X_train_prep = preprocess_imgs(set_name=X_train_crop, img_size=IMG_SIZE)
X_test_prep = preprocess_imgs(set_name=X_test_crop, img_size=IMG_SIZE)
X_val_prep = preprocess_imgs(set_name=X_val_crop, img_size=IMG_SIZE)

# %%
plot_samples(X_train_prep, y_train, labels, 30)
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
# set the paramters we want to change randomly
demo_datagen = ImageDataGenerator(
    rotation_range=15,
    width_shift_range=0.05,
    height_shift_range=0.05,
    rescale=1./255,
    shear_range=0.05,
    brightness_range=[0.1, 1.5],
    horizontal_flip=True,
    vertical_flip=True
)

# %%
os.mkdir('preview')
x = X_train_crop[0]  
x = x.reshape((1,) + x.shape) 

i = 0
for batch in demo_datagen.flow(x, batch_size=1, save_to_dir='preview', save_prefix='aug_img', save_format='jpg'):
    i += 1
    if i > 20:
        break

# %%
plt.imshow(X_train_crop[0])
plt.xticks([])
plt.yticks([])
plt.title('Original Image')
plt.show()

plt.figure(figsize=(15,6))
i = 1
for img in os.listdir('preview/'):
    img = cv2.cv2.imread('preview/' + img)
    img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
    plt.subplot(3,7,i)
    plt.imshow(img)
    plt.xticks([])
    plt.yticks([])
    i += 1
    if i > 3*7:
        break
plt.suptitle('Augemented Images')
plt.show()

# %%
# !rm -rf preview/

# %%
TRAIN_DIR = 'TRAIN_CROP/'
VAL_DIR = 'VAL_CROP/'

train_datagen = ImageDataGenerator(
    rotation_range=15,
    width_shift_range=0.1,
    height_shift_range=0.1,
    shear_range=0.1,
    brightness_range=[0.5, 1.5],
    horizontal_flip=True,
    vertical_flip=True,
    preprocessing_function=preprocess_input
)

test_datagen = ImageDataGenerator(
    preprocessing_function=preprocess_input
)


train_generator = train_datagen.flow_from_directory(
    TRAIN_DIR,
    color_mode='rgb',
    target_size=IMG_SIZE,
    batch_size=15,
    class_mode='binary',
    seed=RANDOM_SEED
)


validation_generator = test_datagen.flow_from_directory(
    VAL_DIR,
    color_mode='rgb',
    target_size=IMG_SIZE,
    batch_size=10,
    class_mode='binary',
    seed=RANDOM_SEED
)
# Out:
# Found 184 images belonging to 2 classes.
# Found 47 images belonging to 2 classes.

# %%
# load base model
vgg16_weight_path = '/content/gdrive/MyDrive/ml/vgg16_weights_tf_dim_ordering_tf_kernels_notop.h5'
#vgg16_weight_path = '/content/gdrive/MyDrive/ml/xception_weights_tf_dim_ordering_tf_kernels.h5'

base_model =  VGG16(
    weights=vgg16_weight_path,
    include_top=False, 
    input_shape=IMG_SIZE + (3,)
)

# %%
NUM_CLASSES = 1

model = Sequential()
model.add(base_model)
model.add(layers.Flatten())
model.add(layers.Dropout(0.5))
model.add(layers.Dense(NUM_CLASSES, activation='sigmoid'))

model.layers[0].trainable = False

model.compile(
    loss='binary_crossentropy',
    optimizer=RMSprop(lr=1e-4),
    metrics=['accuracy']
)

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  vgg16 (Functional)          (None, 7, 7, 512)         14714688
#
#  flatten (Flatten)           (None, 25088)             0
#
#  dropout (Dropout)           (None, 25088)             0
#
#  dense (Dense)               (None, 1)                 25089
#
# =================================================================
# Total params: 14,739,777
# Trainable params: 25,089
# Non-trainable params: 14,714,688
# _________________________________________________________________
# /usr/local/lib/python3.7/dist-packages/keras/optimizer_v2/rmsprop.py:130: UserWarning:
#
# The `lr` argument is deprecated, use `learning_rate` instead.

# %%
EPOCHS = 90
es = EarlyStopping(
    monitor='val_accuracy', 
    mode='max',
    patience=6
)

history = model.fit(
    train_generator,
    steps_per_epoch=10,
    epochs=EPOCHS,
    validation_data=validation_generator,
    validation_steps=5,
    #callbacks=[es]
)
# Out:
# Epoch 1/90
# 10/10 [==============================] - 20s 861ms/step - loss: 0.8478 - accuracy: 0.4604 - val_loss: 0.5532 - val_accuracy: 0.7447
# Epoch 2/90
# 10/10 [==============================] - 4s 410ms/step - loss: 0.7050 - accuracy: 0.5540 - val_loss: 0.4869 - val_accuracy: 0.8298
# Epoch 3/90
# 10/10 [==============================] - 4s 353ms/step - loss: 0.5501 - accuracy: 0.7050 - val_loss: 0.4629 - val_accuracy: 0.7872
# Epoch 4/90
# 10/10 [==============================] - 4s 347ms/step - loss: 0.5494 - accuracy: 0.7122 - val_loss: 0.4085 - val_accuracy: 0.8298
# Epoch 5/90
# 10/10 [==============================] - 4s 385ms/step - loss: 0.5176 - accuracy: 0.7050 - val_loss: 0.3820 - val_accuracy: 0.8085
# Epoch 6/90
# 10/10 [==============================] - 4s 350ms/step - loss: 0.4957 - accuracy: 0.7770 - val_loss: 0.3669 - val_accuracy: 0.8511
# Epoch 7/90
# 10/10 [==============================] - 4s 348ms/step - loss: 0.4974 - accuracy: 0.7554 - val_loss: 0.3581 - val_accuracy: 0.8085
# Epoch 8/90
# 10/10 [==============================] - 3s 368ms/step - loss: 0.4389 - accuracy: 0.8489 - val_loss: 0.3448 - val_accuracy: 0.8085
# Epoch 9/90
# 10/10 [==============================] - 4s 350ms/step - loss: 0.4233 - accuracy: 0.8345 - val_loss: 0.3358 - val_accuracy: 0.8936
# Epoch 10/90
# 10/10 [==============================] - 4s 345ms/step - loss: 0.3681 - accuracy: 0.8633 - val_loss: 0.3186 - val_accuracy: 0.8511
# Epoch 11/90
# 10/10 [==============================] - 4s 349ms/step - loss: 0.3901 - accuracy: 0.8345 - val_loss: 0.3214 - val_accuracy: 0.8085
# Epoch 12/90
# 10/10 [==============================] - 3s 365ms/step - loss: 0.3456 - accuracy: 0.8705 - val_loss: 0.3018 - val_accuracy: 0.8511
# Epoch 13/90
# 10/10 [==============================] - 4s 351ms/step - loss: 0.3433 - accuracy: 0.8633 - val_loss: 0.3137 - val_accuracy: 0.8085
# Epoch 14/90
# 10/10 [==============================] - 4s 359ms/step - loss: 0.3282 - accuracy: 0.8533 - val_loss: 0.2780 - val_accuracy: 0.8723
# Epoch 15/90
ms/step - loss: 0.0368 - accuracy: 1.0000 - val_loss: 0.1910 - val_accuracy: 0.8936
# Epoch 77/90
# 10/10 [==============================] - 4s 365ms/step - loss: 0.0429 - accuracy: 0.9933 - val_loss: 0.2080 - val_accuracy: 0.8723
# Epoch 78/90
# 10/10 [==============================] - 4s 350ms/step - loss: 0.0511 - accuracy: 0.9856 - val_loss: 0.1582 - val_accuracy: 0.9149
# Epoch 79/90
# 10/10 [==============================] - 4s 351ms/step - loss: 0.0449 - accuracy: 0.9856 - val_loss: 0.1624 - val_accuracy: 0.9149
# Epoch 80/90
# 10/10 [==============================] - 4s 349ms/step - loss: 0.0585 - accuracy: 0.9856 - val_loss: 0.2109 - val_accuracy: 0.8723
# Epoch 81/90
# 10/10 [==============================] - 4s 366ms/step - loss: 0.0451 - accuracy: 0.9867 - val_loss: 0.1625 - val_accuracy: 0.9149
# Epoch 82/90
# 10/10 [==============================] - 4s 352ms/step - loss: 0.0572 - accuracy: 0.9784 - val_loss: 0.1548 - val_accuracy: 0.9149
# Epoch 83/90
# 10/10 [==============================] - 4s 347ms/step - loss: 0.0439 - accuracy: 0.9856 - val_loss: 0.1397 - val_accuracy: 0.9362
# Epoch 84/90
# 10/10 [==============================] - 3s 346ms/step - loss: 0.0387 - accuracy: 0.9928 - val_loss: 0.1527 - val_accuracy: 0.9149
# Epoch 85/90
# 10/10 [==============================] - 4s 350ms/step - loss: 0.0285 - accuracy: 0.9928 - val_loss: 0.1638 - val_accuracy: 0.9149
# Epoch 86/90
# 10/10 [==============================] - 3s 343ms/step - loss: 0.0471 - accuracy: 0.9928 - val_loss: 0.1545 - val_accuracy: 0.9149
# Epoch 87/90
# 10/10 [==============================] - 4s 353ms/step - loss: 0.0347 - accuracy: 0.9928 - val_loss: 0.1482 - val_accuracy: 0.9149
# Epoch 88/90
# 10/10 [==============================] - 4s 348ms/step - loss: 0.0359 - accuracy: 0.9928 - val_loss: 0.1690 - val_accuracy: 0.9149
# Epoch 89/90
# 10/10 [==============================] - 4s 362ms/step - loss: 0.0408 - accuracy: 0.9867 - val_loss: 0.1806 - val_accuracy: 0.8936
# Epoch 90/90
# 10/10 [==============================] - 4s 348ms/step - loss: 0.0377 - accuracy: 0.9928 - val_loss: 0.1608 - val_accuracy: 0.9149

# %%
# plot model performance
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']
loss = history.history['loss']
val_loss = history.history['val_loss']
epochs_range = range(1, len(history.epoch) + 1)

plt.figure(figsize=(15,5))

plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Train Set')
plt.plot(epochs_range, val_acc, label='Val Set')
plt.legend(loc="best")
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.title('Model Accuracy')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Train Set')
plt.plot(epochs_range, val_loss, label='Val Set')
plt.legend(loc="best")
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Model Loss')

#plt.tight_layout()
plt.show()

# %%
# validate on val set
predictions = model.predict(X_val_prep)
predictions = [1 if x>0.5 else 0 for x in predictions]

accuracy = accuracy_score(y_val, predictions)
print('Val Accuracy = %.2f' % accuracy)

confusion_mtx = confusion_matrix(y_val, predictions) 
cm = plot_confusion_matrix(confusion_mtx, classes = list(labels.items()), normalize=False)
# Out:
# Val Accuracy = 0.94

# %%
# validate on test set
predictions = model.predict(X_test_prep)
predictions = [1 if x>0.5 else 0 for x in predictions]

accuracy = accuracy_score(y_test, predictions)
print('Test Accuracy = %.2f' % accuracy)

confusion_mtx = confusion_matrix(y_test, predictions) 
cm = plot_confusion_matrix(confusion_mtx, classes = list(labels.items()), normalize=False)
# Out:
# Test Accuracy = 1.00

# %%
ind_list = np.argwhere((y_test == predictions) == False)[:, -1]
if ind_list.size == 0:
    print('There are no missclassified images.')
else:
    for i in ind_list:
        plt.figure()
        plt.imshow(X_test_crop[i])
        plt.xticks([])
        plt.yticks([])
        plt.title(f'Actual class: {y_val[i]}\nPredicted class: {predictions[i]}')
        plt.show()
# Out:
# There are no missclassified images.
